# %%
# %run gpCAM_Physics_compare_Exp_data.ipynb
# Out:
# [True, True, True, True]
# [False, False, False, False]
# [False, False, False, True]
# [False, False, False, False]
# [False, False, False, True]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, True]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, True]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, False]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, False]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, True]
# [False, False, False, False]
# [False, False, False, False]
# ...

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])
